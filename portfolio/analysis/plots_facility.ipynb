# %%
import numpy as np
import cvxpy as cp
from scipy.spatial.distance import cdist
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.special import gamma
import itertools
import time
import mosek
from mpl_toolkits.axes_grid1.inset_locator import mark_inset, zoomed_inset_axes
import pandas as pd

# %%
df = pd.read_csv('df_0.csv')

# %%
plt.plot(df['DRO_obj_values'])
plt.plot(df['DRO_eval1'])
plt.plot(df['SA_obj_values'])
plt.plot(df['SA_eval1'])

# plt.plot(df['MRO_obj_values'])
# plt.plot(df['MRO_eval1'])
# plt.plot(df['obj_values'])
# plt.plot(df['O_eval1'])
# df['MRO_satisfy1']

# %%
plt.plot(df['epsilon'])
plt.plot([0.0005*(1/(t**(1/(20)))) for t in range(5,100)])

# %%
plt.plot(df['t'][:257:2],df['MRO_obj_values'][257*8:9*257:2])
plt.plot(df['t'][:257:2],df['obj_values'][257*8:9*257:2])
plt.plot(df['t'][:257:2],df['MRO_eval0'][257*8:9*257:2],linestyle = ':')
plt.plot(df['t'][:257:2],df['O_eval0'][257*8:9*257:2],linestyle = ':')
plt.show()

# plt.plot(df['MRO_satisfy_p0'],linestyle = '-')
# plt.plot(df['satisfy_p0'],linestyle = '-')
# plt.show()


plt.plot(df['MRO_satisfy0'],linestyle = '-')
plt.plot(df['O_satisfy0'],linestyle = '-')
plt.show()

plt.plot(df['t'][:257:2],df['MRO_time'][257*8:9*257:2],linestyle = '-')
plt.plot(df['t'][:257:2],df['online_time'][257*8:9*257:2],linestyle = '-')
plt.yscale("log")
# plt.plot(df['online_time'],linestyle = '-')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 plt.plot(df['t'][:257:2],df['MRO_obj_values'][257*8:9*257:2])
#       2 plt.plot(df['t'][:257:2],df['obj_values'][257*8:9*257:2])
#       3 plt.plot(df['t'][:257:2],df['MRO_eval0'][257*8:9*257:2],linestyle = ':')
#
# File ~/anaconda3/envs/mro/lib/python3.10/site-packages/matplotlib/pyplot.py:2767, in plot(scalex, scaley, data, *args, **kwargs)
#    2765 @_copy_docstring_and_deprecators(Axes.plot)
#    2766 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
#    2769         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/envs/mro/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1635, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1393 """
# ...
