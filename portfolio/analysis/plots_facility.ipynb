# %%
import numpy as np
import cvxpy as cp
from scipy.spatial.distance import cdist
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.special import gamma
import itertools
import time
import mosek
from mpl_toolkits.axes_grid1.inset_locator import mark_inset, zoomed_inset_axes
import pandas as pd

# %%
df = pd.read_csv('df_0.csv')

# %%
# plt.plot(df['DRO_satisfy1'])

plt.plot(df['DRO_time'])
plt.plot(df['SA_time'])

# %%
# plt.plot(df['DRO_obj_values'], label="DRO")
# plt.plot(df['DRO_eval1'],label="DRO_eval")
# plt.plot(df['SA_obj_values'],label = "SA")
# plt.plot(df['SA_eval1'],label = "SA_eval")
# plt.legend()
# plt.show()

plt.plot(df['MRO_obj_values'],label = "MRO")
plt.plot(df['MRO_eval1'], label="MRO_eval")
plt.plot(df['obj_values'], label = "recluster")
plt.plot(df['O_eval1'],label = "recluster_eval")
plt.legend()
# df['MRO_satisfy1']

# %%
plt.plot(df['epsilon'])
plt.plot([0.05*(1/(t**(1/(10)))) for t in range(5,100)])
